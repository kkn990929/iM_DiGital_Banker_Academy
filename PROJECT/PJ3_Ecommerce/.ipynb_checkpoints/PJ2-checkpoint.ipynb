# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
matplotlib.rc('font', family = 'Malgun Gothic')
matplotlib.rc('axes', unicode_minus=False)
warnings.filterwarnings('ignore')

# %%
df_product = pd.read_csv('product_data.csv')
df_product.head()
# Out:
#          제품번호      물품명  물품대분류   물품중분류       상품중량
# 0  100021V2_0    2단무늬컵  식기/편백      자기         1p
# 1  100022V2_1  7곡딸기롤과자     과자      스낵  100g/10개입
# 2  100023V2_2     7곡참식   식사대용   선식/생식       700g
# 3  100024V2_3      가리비   생물수산  패류/갑각류      1.5kg
# 4  100025V2_3      가리비   생물수산  패류/갑각류        1kg

# %%
df_member = pd.read_csv('member_data.csv', encoding='cp949')
df_member.head()
# Out:
#        회원번호  회원상태 성별  나이   등록카드   결혼   구독여부    주소지 세부주소지
# 0  18764160  정상회원  여  68  농협중앙회   기혼  False  서울특별시   성동구
# 1  18792000  정상회원  남  83  연결앱결제  NaN  False    강원도   강릉시
# 2  18942336  정상회원  여  39   신한은행   기혼  False  인천광역시    중구
# 3  18949760  정상회원  여  73   기업은행  NaN    NaN    강원도   홍천군
# 4  19391488  정상회원  여  52  연결앱결제   기혼  False  대전광역시    중구

# %%
df_sales = pd.read_csv('sales_data.csv',encoding='cp949')
df_sales.head()
# Out:
#          회원번호  회원상태  구매수량   구매금액        주문일시       배송시작일       배송완료일  사용 적립금  \
# 0  1032097472  정상회원   1.0   7083  2022-01-08         NaN         NaN       0
# 1  1032097472  정상회원   1.0  29865  2022-01-08  2022-01-08  2022-01-08       0
# 2  1032097472  정상회원   1.0  23164  2022-01-08  2022-01-08  2022-01-09       0
# 3   369152832  정상회원   1.0  16655  2022-01-08  2022-01-08  2022-01-09       0
# 4  1032097472  정상회원   1.0   8423  2022-01-08         NaN         NaN       0
#
#    사용 포인트 네이버 주문취소여부      주문시간              제품번호
# 0           0   주문취소  오후 12:60  100021783V2_1337
# 1           0    NaN  오후 12:60  100022137V2_1606
# 2           0    NaN  오후 12:60  100021452V2_1113
# 3           0    NaN  오후 12:60    10002931V2_708
# 4           0   주문취소  오후 12:60  100022085V2_1559

# %%
df_product['물품중분류'].unique()
# Out:
# array(['자기', '스낵', '선식/생식', '패류/갑각류', '옹기', '돼지(중량)', '발효음료', '과즙',
#        '가시오이', '냉동생선', '가지', '가지말림', '게장/게살', '소스', '돈가스/분쇄가공', '수산가공반찬',
#        '만가닥버섯', '양송이버섯', '귤(비가림)', '귤만감', '빙과', '곶감', '식초', '음료기타', '잎꽃차',
#        '라면', '건강곡물빵', '과채가루', '생숙면', '기타해조류', '갓', '기타채소', '갓끈동부', '풋콩',
#        '환경용품', '개복숭아', '살균/세정/탈취', '분말/환', '건고추', '곡류차', '건대추', '말린도라지',
#        '목이버섯', '기타건어류', '국.찌개', '건강차', '장류/기타', '두유', '깨', '콩', '밤',
#        '엿/양갱/기타', '묵', '피자/핫도그', '고구마순', '고구마순말림(70g)', '찐빵,호떡,전통',
#        '케이크,롤,선물', '만두', '기타', '부각/튀각', '햄/소시지/훈제', '볶음', '기타양념', '고춧가루',
#        '고춧잎', '프리믹스', '씨리얼', '곤드레나물/손질', '식사대용/기타', '곤드레잎', '기타생활용품',
#        '곰취', '무항생제닭', '기타냉동수산', '유기한우', '공심채', '잼', '푸딩', '김', '김가공',
#        '유정란', '보리살림돼지', '대용량물품(냉동수산)', '가공소금', '멸치류', '황태류', '천일염',
#        '스테인리스', '화본', '귤(조생)', '숯/원예', '근대', '금이버섯', '한과/유과', '간편요리',
#        '배추', '젓갈/액젓', '무', '더덕/손질', '도라지/손질', '깐마늘', '은행', '쪽파', '호두',
# ...

# %%
for i in df['물품대분류'].unique():
    print(f' 대분류 : {i}')
    # print(df[df['물품대분류'] == i]['물품중분류'].unique()) # 대분류별 중분류 확인
# Out:
#  대분류 : 식기/편백
#  대분류 : 과자
#  대분류 : 식사대용
#  대분류 : 생물수산
#  대분류 : 중량(정육)
#  대분류 : 음료
#  대분류 : 열매채소
#  대분류 : 냉동수산
#  대분류 : 말린나물/건재
#  대분류 : 수산가공
#  대분류 : 소스/기타양념
#  대분류 : 육가공
#  대분류 : 버섯
#  대분류 : 과일
#  대분류 : 기름/식초
#  대분류 : 차
#  대분류 : 밀가공
#  대분류 : 빵
#  대분류 : 가루
#  대분류 : 해조
#  대분류 : 잎/줄기채소
#  대분류 : 김치
#  대분류 : 생활용품
#  대분류 : 세제/세안
#  대분류 : 건강일반
#  대분류 : 양념채소
#  대분류 : 건어물
#  대분류 : 즉석조리
#  대분류 : 장
#  대분류 : 콩/화본/깨
#  대분류 : 견과
#  대분류 : 어묵/묵
#  대분류 : 밑반찬
#  대분류 : 닭/오리
#  대분류 : 소
#  대분류 : 잼/병조림/기타
#  대분류 : 알
#  대분류 : 돼지
#  대분류 : 소금
#  대분류 : 뿌리채소
#  대분류 : 떡
#  대분류 : 홍삼/녹용
#  대분류 : 쌈채소류
#  대분류 : 꿀
#  대분류 : 과실주
#  대분류 : 과일채소
#  대분류 : 유색미/발아미
#  대분류 : 두부/유부
#  대분류 : 절임/장아찌
#  대분류 : 유제품
#  대분류 : 전통주
#  대분류 : 멥쌀
#  대분류 : 보리/혼합곡
#  대분류 : 화장품
#  대분류 : 콩나물
#  대분류 : 손질한채소
#  대분류 : 섬유
#  대분류 : 찹쌀
#  대분류 : 김장채소

# %%
# df_product['상품중량'].unique()

# %%
대분류 : 과일채소
['냉동딸기' '냉동메론' '딸기' '메론' '방울토마토' '수박' '완숙토마토' '참외']

# %%
df_product[df_product['물품대분류'] == '생활용품']
# Out:
#                   제품번호          물품명 물품대분류   물품중분류      상품중량
# 72        1000273V2_52    개별절전멀티콘센트  생활용품    환경용품   2구/1.5m
# 73        1000274V2_52    개별절전멀티콘센트  생활용품    환경용품   4구/1.5m
# 139     10002140V2_111       곰돌이주머니  생활용품  기타생활용품        1장
# 211     10002212V2_165         그로우백  생활용품    숯/원예     미니/초록
# 212     10002213V2_165         그로우백  생활용품    숯/원예  열매채소용/초록
# ...                ...          ...   ...     ...       ...
# 2417  100022418V2_1811       항아리 꿀초  생활용품    환경용품       NaN
# 2498  100022499V2_1879        화분용퇴비  생활용품    숯/원예       1kg
# 2499  100022500V2_1879        화분용퇴비  생활용품    숯/원예       5kg
# 2524  100022525V2_1902  휴대용 치약/칫솔모음  생활용품   치약/칫솔        감귤
# 2525  100022526V2_1902  휴대용 치약/칫솔모음  생활용품   치약/칫솔      하늘바다
#
# [101 rows x 5 columns]

# %%
# data = pd.read_csv('data.csv',encoding='cp949')
# data.head()

# %% [markdown]
# # 대대분류 분할

# %%
# 대분류별 차이를 구
