# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from statsmodels.stats.proportion import proportions_ztest
from scipy.stats import ttest_ind
from scipy.stats import bartlett
from scipy.stats import f_oneway
from scipy.stats import chi2_contingency
from scipy.stats import pearsonr

# %%
df = pd.read_csv('data_RMF_final_real.csv')
df
# Out:
#         Unnamed: 0.1  Unnamed: 0        회원번호  회원상태  구매수량    구매금액        주문일시  \
# 0                  0           0  1032097472  정상회원   1.0    7083  2022-01-08
# 1                  1           1  1032097472  정상회원   1.0   10338  2022-09-16
# 2                  2           2  1032097472  정상회원   1.0   10338  2022-06-18
# 3                  3           3  1032097472  정상회원   1.0   10338  2022-04-02
# 4                  4           4  1032097472  정상회원   1.0    8615  2022-05-07
# ...              ...         ...         ...   ...   ...     ...         ...
# 662690        662690      662690   734192768  정상회원   1.0   30631  2022-05-01
# 662691        662691      662691  1352610112  정상회원   1.0  122523  2022-10-31
# 662692        662692      662692  1556603072  정상회원   1.0   56475  2022-10-29
# 662693        662693      662693   686955712  정상회원   1.0  109122  2022-06-12
# 662694        662694      662694   686955712  정상회원   1.0  109122  2022-06-21
#
#              배송시작일       배송완료일  사용 적립금  ...  가격대 관심물품중분류 Recency Frequency  \
# 0              NaN         NaN       0  ...   중가      두부       8        63
# 1       2022-09-17  2022-09-18       0  ...   중가      두부       8        63
# 2       2022-06-18  2022-06-18       0  ...   중가      두부       8        63
# 3       2022-04-02  2022-04-02       0  ...   중가      두부       8        63
# 4       2022-05-07  2022-05-08       0  ...   중가      두부       8        63
# ...            ...         ...     ...  ...  ...     ...     ...       ...
# 662690  2022-05-02  2022-05-03       0  ...   고가      옹기      13         5
# 662691  2022-10-31  2022-10-31       0  ...   고가     무화과       2        17
# 662692  2022-10-29  2022-10-31       0  ...   중가     깐마늘       8        42
# 662693  2022-06-13  2022-06-13       0  ...   고가      편백      46        21
# 662694  2022-06-21  2022-06-22       0  ...   고가      편백      46        21
#
#        Monetary  R  F  M  RFM_Score  Customer_Type
# 0        733696  4  4  4        4.0           일반고객
# 1        733696  4  4  4        4.0           일반고객
# 2        733696  4  4  4        4.0           일반고객
# 3        733696  4  4  4        4.0           일반고객
# 4        733696  4  4  4        4.0           일반고객
# ...         ... .. .. ..        ...            ...
# 662690    89786  4  2  2        2.8           잠재고객
# 662691   322387  5  3  4        4.2           우수고객
# 662692   465299  4  4  4        4.0           일반고객
# 662693   898819  3  3  5        3.8           일반고객
# 662694   898819  3  3  5        3.8           일반고객
#
# [662695 rows x 51 columns]
