# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import FinanceDataReader as fdr

# %%
F = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML2-0819/datas/COMP/마니커에프앤지.csv")

# %%
FNG.head()
# Out:
#          Date  Open  High   Low  Close    Volume    Change
# 0  2019-08-20  7135  9276  6198   6199  16932834       NaN
# 1  2019-08-21  6234  7938  5842   7403  12941725  0.194225
# 2  2019-08-22  7072  8473  6823   6984   9593033 -0.056599
# 3  2019-08-23  7055  8018  6885   7510   6470346  0.075315
# 4  2019-08-26  7197  7456  6609   6609   1420941 -0.119973

# %%
plt.figure(figsize=(10, 6))
plt.plot(FNG['Date'], FNG['Close'], marker='o')
plt.title('Date vs Close')
# plt.xlabel('Date')
# plt.ylabel('Close')
# plt.grid(True)
# plt.xticks(rotation=45)
plt.show()

# %%
LNF = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML2-0819/datas/COMP/엘앤에프.csv")

# %%
plt.figure(figsize=(10, 6))
plt.plot(LNF['Date'], LNF['Close'], marker='o')
plt.title('Date vs Close')
# plt.xlabel('Date')
# plt.ylabel('Close')
# plt.grid(True)
# plt.xticks(rotation=45)
plt.show()

# %%
KAKAO = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML2-0819/datas/COMP/카카오.csv")

# %%
plt.figure(figsize=(10, 6))
plt.plot(KAKAO['Date'], KAKAO['Close'], marker='o')
plt.title('Date vs Close')
# plt.xlabel('Date')
# plt.ylabel('Close')
# plt.grid(True)
# plt.xticks(rotation=45)
plt.show()

# %%
LG = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML2-0819/datas/COMP/LG.csv")

# %%
plt.figure(figsize=(10, 6))
plt.plot(LG['Date'], LG['Close'])
plt.title('Date vs Close')
# plt.xlabel('Date')
# plt.ylabel('Close')
# plt.grid(True)
# plt.xticks(rotation=45)
plt.show()

# %%
HanhwaOcean = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML2-0819/datas/COMP/한화오션.csv")

# %%
plt.figure(figsize=(10, 6))
plt.plot(HanhwaOcean['Date'], HanhwaOcean['Close'])
plt.title('Date vs Close')
# plt.xlabel('Date')
# plt.ylabel('Close')
# plt.grid(True)
# plt.xticks(rotation=45)
plt.show()

# %%
krelec = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML2-0819/datas/COMP/한국전력.csv")
plt.figure(figsize=(10, 6))
plt.plot(krelec['Date'], krelec['Close'])
plt.title('Date vs Close')
# plt.xlabel('Date')
# plt.ylabel('Close')
# plt.grid(True)
# plt.xticks(rotation=45)
plt.show()

# %%
Lottech = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML2-0819/datas/COMP/롯데칠성.csv")
plt.figure(figsize=(10, 6))
plt.plot(Lottech['Date'], Lottech['Close'])
plt.title('Date vs Close')
# plt.xlabel('Date')
# plt.ylabel('Close')
# plt.grid(True)
# plt.xticks(rotation=45)
plt.show()

# %%
df = fdr.DataReader('068270', '2017')
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# KS11 (KOSPI 지수), 2015년~현재
df = fdr.DataReader('KS11', '2015')
df['Close'].plot()
# Out:
# 1 001 2015-01-01 00:00:00 2016-12-31 00:00:00
# 1 001 2017-01-01 00:00:00 2018-12-31 00:00:00
# 1 001 2019-01-01 00:00:00 2020-12-31 00:00:00
# 1 001 2021-01-01 00:00:00 2022-12-31 00:00:00
# 1 001 2023-01-01 00:00:00 2024-12-31 00:00:00
# <Axes: xlabel='Date'>
