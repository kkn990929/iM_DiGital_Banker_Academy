# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML2-0819/datas/COMP/stock_info_final.csv")

# %%
df
# Out:
#       Unnamed: 0    종목코드     종목명     EPS    PER      BPS   PBR  주당배당금  배당수익률
# 0              0   60310      3S    30.0  74.83    947.0  2.37      0   0.00
# 1              1   95570  AJ네트웍스   367.0  12.28   9326.0  0.48    270   5.99
# 2              2    6840   AK홀딩스  2635.0   4.87  44339.0  0.29    200   1.56
# 3              3   54620     APS   667.0   9.43  11683.0  0.54      0   0.00
# 4              4  265520   AP시스템  3997.0   4.90  21396.0  0.92    270   1.38
# ...          ...     ...     ...     ...    ...      ...   ...    ...    ...
# 1504        1504  189980  흥국에프엔비   221.0   8.59   2449.0  0.78     40   2.11
# 1505        1505     540    흥국화재  4664.0   0.89  20881.0  0.20      0   0.00
# 1506        1506    3280    흥아해운   142.0  15.99    690.0  3.29      0   0.00
# 1507        1507   37440      희림   489.0  11.39   5583.0  1.00    150   2.69
# 1508        1508  238490      힘스   511.0   9.29   6174.0  0.77     50   1.05
#
# [1509 rows x 9 columns]
