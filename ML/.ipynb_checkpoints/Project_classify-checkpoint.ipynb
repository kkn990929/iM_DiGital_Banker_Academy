# %%
# 필요한 라이브러리 불러오기
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
from sklearn.datasets import make_classification
# 필요한 라이브러리 임포트
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
# 데이터 셋 구분


df_train = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML/Project/datas/df_train.csv")
df_test = pd.read_csv("C:/Users/campus4D037/iM DiGital Bank/ML/Project/datas/df_test.csv")
pd.set_option('display.precision', 8)
df_train = df_train.drop(columns='Unnamed: 0')
df_test = df_test.drop(columns='Unnamed: 0')

# %%
features_to_scale = ['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']
# StandardScaler 인스턴스 생성
scaler = StandardScaler()

# 스케일링 적용
df_train[features_to_scale] = scaler.fit_transform(df_train[features_to_scale])

df_train
# Out:
#      위치          일자        현재발전출력      수평일사량1      수평일사량2      경사일사량1  \
# 0     A  2019-01-01  110.65736944 -0.64966747 -0.19104126 -0.78774030
# 1     A  2019-01-02  328.85723337  0.75455893  1.44389799  0.66290233
# 2     A  2019-01-03  344.74021549  0.97294269  1.83051460  0.88512248
# 3     A  2019-01-04  359.59558933  0.79152490  1.52813393  0.64820788
# 4     A  2019-01-05  358.73768471  0.54590796  1.31150352  0.40603652
# ...  ..         ...           ...         ...         ...         ...
# 9120  E  2020-12-27  270.29591220 -1.37347293 -1.00766932  1.53597804
# 9121  E  2020-12-28  280.03494669 -0.90401941 -1.26113704  0.90618842
# 9122  E  2020-12-29  847.48891271 -1.08301088 -1.28812297  1.15993230
# 9123  E  2020-12-30   93.01245905  0.33246570 -0.71911636  0.31841915
# 9124  E  2020-12-31  378.82318610  1.21882773 -0.84644329 -0.09640909
#
#           경사일사량2       외기온도1       외기온도2    년도   월
# 0    -0.29532931  0.50181520  0.82417563  2019   1
# ...

# %%
features_to_scale = ['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']
# StandardScaler 인스턴스 생성
scaler = StandardScaler()

# 스케일링 적용
df_test[features_to_scale] = scaler.fit_transform(df_test[features_to_scale])

df_test
# Out:
#      위치          일자        현재발전출력      수평일사량1      수평일사량2      경사일사량1  \
# 0     A  2021-01-01   96.01971914  0.79521938  0.98855417 -0.03822649
# 1     A  2021-01-02   35.47195094  1.01619127  1.02015562  0.55766079
# 2     A  2021-01-03   84.25522665  0.67858041 -1.23007971 -0.28635386
# 3     A  2021-01-04  261.80651625  0.95942301 -0.75658471  0.09318019
# 4     A  2021-01-05  156.21756072  0.20073442 -0.62660604  0.80560183
# ...  ..         ...           ...         ...         ...         ...
# 1820  E  2021-12-27  415.50301545 -0.53509255 -0.77964706 -1.31397231
# 1821  E  2021-12-28  434.31634733 -1.15851279 -0.88159080 -0.91497169
# 1822  E  2021-12-29  794.31737731  1.03436872 -1.17338167  0.94002540
# 1823  E  2021-12-30    5.89951751  0.40253156 -0.67204901  1.24339174
# 1824  E  2021-12-31  496.24349871 -0.04868515 -0.92627247  0.15736228
#
#           경사일사량2       외기온도1       외기온도2    년도   월
# 0     0.62330757 -0.96889739 -1.22863487  2021   1
# ...

# %%
df_train['현재발전출력_div'] = df_train.apply(lambda row: 1 if row['일자'] == 'A' and row['현재발전출력'] >= 294 else 0, axis=1)
df_train
# Out:
#      위치          일자        현재발전출력      수평일사량1      수평일사량2      경사일사량1  \
# 0     A  2019-01-01  110.65736944 -0.64966747 -0.19104126 -0.78774030
# 1     A  2019-01-02  328.85723337  0.75455893  1.44389799  0.66290233
# 2     A  2019-01-03  344.74021549  0.97294269  1.83051460  0.88512248
# 3     A  2019-01-04  359.59558933  0.79152490  1.52813393  0.64820788
# 4     A  2019-01-05  358.73768471  0.54590796  1.31150352  0.40603652
# ...  ..         ...           ...         ...         ...         ...
# 9120  E  2020-12-27  270.29591220 -1.37347293 -1.00766932  1.53597804
# 9121  E  2020-12-28  280.03494669 -0.90401941 -1.26113704  0.90618842
# 9122  E  2020-12-29  847.48891271 -1.08301088 -1.28812297  1.15993230
# 9123  E  2020-12-30   93.01245905  0.33246570 -0.71911636  0.31841915
# 9124  E  2020-12-31  378.82318610  1.21882773 -0.84644329 -0.09640909
#
#           경사일사량2       외기온도1       외기온도2    년도   월  현재발전출력_div
# 0    -0.29532931  0.50181520  0.82417563  2019   1           0
# ...

# %%
df_train_a = df_train[df_train['위치'] == 'A']
df_train_b = df_train[df_train['위치'] == 'B']
df_train_c = df_train[df_train['위치'] == 'C']
df_train_d = df_train[df_train['위치'] == 'D']
df_train_e = df_train[df_train['위치'] == 'E']

# %%
df_test_a = df_test[df_test['위치'] == 'A']
df_test_b = df_test[df_test['위치'] == 'B']
df_test_c = df_test[df_test['위치'] == 'C']
df_test_d = df_test[df_test['위치'] == 'D']
df_test_e = df_test[df_test['위치'] == 'E']

# %%
df_test_a['현재발전출력_div'] = df_test_a['현재발전출력'].apply(lambda x: 0 if x <= 294 else 1)
df_test_b['현재발전출력_div'] = df_test_b['현재발전출력'].apply(lambda x: 0 if x <= 9848 else 1)
df_test_c['현재발전출력_div'] = df_test_c['현재발전출력'].apply(lambda x: 0 if x <= 426 else 1)
df_test_d['현재발전출력_div'] = df_test_d['현재발전출력'].apply(lambda x: 0 if x <= 36 else 1)
df_test_e['현재발전출력_div'] = df_test_e['현재발전출력'].apply(lambda x: 0 if x <= 828 else 1)
# Out:
# C:\Users\campus4D037\AppData\Local\Temp\ipykernel_24048\2667387502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_a['현재발전출력_div'] = df_test_a['현재발전출력'].apply(lambda x: 0 if x <= 294 else 1)
# C:\Users\campus4D037\AppData\Local\Temp\ipykernel_24048\2667387502.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_b['현재발전출력_div'] = df_test_b['현재발전출력'].apply(lambda x: 0 if x <= 9848 else 1)
# ...

# %%
df_train_a['현재발전출력_div'] = df_train_a['현재발전출력'].apply(lambda x: 0 if x <= 294 else 1)
df_train_b['현재발전출력_div'] = df_train_b['현재발전출력'].apply(lambda x: 0 if x <= 9848 else 1)
df_train_c['현재발전출력_div'] = df_train_c['현재발전출력'].apply(lambda x: 0 if x <= 426 else 1)
df_train_d['현재발전출력_div'] = df_train_d['현재발전출력'].apply(lambda x: 0 if x <= 36 else 1)
df_train_e['현재발전출력_div'] = df_train_e['현재발전출력'].apply(lambda x: 0 if x <= 828 else 1)
# Out:
# C:\Users\campus4D037\AppData\Local\Temp\ipykernel_24048\1663567930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_a['현재발전출력_div'] = df_train_a['현재발전출력'].apply(lambda x: 0 if x <= 294 else 1)
# C:\Users\campus4D037\AppData\Local\Temp\ipykernel_24048\1663567930.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_b['현재발전출력_div'] = df_train_b['현재발전출력'].apply(lambda x: 0 if x <= 9848 else 1)
# ...

# %%
df_train_d
# Out:
#      위치          일자       현재발전출력      수평일사량1      수평일사량2      경사일사량1  \
# 5475  D  2016-01-01  29.82623577  1.04625766  0.55462264  1.22755144
# 5476  D  2016-01-02  39.03483413  1.12798778  0.96820766  1.30622160
# 5477  D  2016-01-03  31.22355493  1.35982385  0.68097926  1.55906853
# 5478  D  2016-01-04  36.69080701  1.09992683  0.79765208  1.28751060
# 5479  D  2016-01-05  17.67764430  0.48609216 -0.23183812  0.51030480
# ...  ..         ...          ...         ...         ...         ...
# 7295  D  2020-12-27  27.33060822 -1.16287744  0.70494671  0.03463755
# 7296  D  2020-12-28  23.88168349  1.18216941  0.39934228  0.94602911
# 7297  D  2020-12-29  23.21369809  1.23629024  0.86625042  1.00903058
# 7298  D  2020-12-30   5.13045896 -0.60923026 -0.93658856 -0.97063332
# 7299  D  2020-12-31  10.55114736  0.31685830 -0.90043639 -0.01813215
#
#           경사일사량2       외기온도1       외기온도2    년도   월  현재발전출력_div
# 5475  0.61685054 -0.69792604 -1.03951470  2016   1           0
# ...

# %%
# x_train_a = df_train_a[['수평일사량1', '수평일사량2','경사일사량1','경사일사량2','외기온도1','외기온도2']]
# x_test_a = df_test_a[['수평일사량1', '수평일사량2','경사일사량1','경사일사량2','외기온도1','외기온도2']]

# y_train_a = df_train_a[['현재발전출력_div']]
# y_test_a = df_test_a[['현재발전출력_div']]

# %%
x_train_a = df_train_a[['수평일사량1', '수평일사량2','경사일사량1','경사일사량2','외기온도1','외기온도2']]
x_test_a = df_test_a[['수평일사량1', '수평일사량2','경사일사량1','경사일사량2','외기온도1','외기온도2']]

y_train_a = df_train_a[['현재발전출력_div']]
y_test_a = df_test_a[['현재발전출력_div']]
# 랜덤포레스트 분류기 모델 초기화
rf_model_a = RandomForestClassifier(n_estimators=100, random_state=42)

# 모델 훈련
rf_model_a.fit(x_train_a, y_train_a)

# 테스트 세트에 대한 예측
y_pred_a = rf_model_a.predict(x_test_a)

# 정확도 계산
accuracy = accuracy_score(y_test_a, y_pred_a)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_a, y_pred_a)
recall = recall_score(y_test_a, y_pred_a)
precision = precision_score(y_test_a, y_pred_a)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_a, y_pred_a)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('RF classifier - Area A')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_a, y_pred_a, target_names=['Negative (0)', 'Positive (1)']))
# Out:
# C:\Users\campus4D037\AppData\Local\Temp\ipykernel_24048\3032462512.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_model_a.fit(x_train_a, y_train_a)
# RF classifier - Area A
# Accuracy(정확도): 0.66
# F1 Score: 0.13
# Recall(재현도): 0.07
# Precision(정밀도): 0.60
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.66      0.97      0.79       238
# Positive (1)       0.60      0.07      0.13       127
#
#     accuracy                           0.66       365
#    macro avg       0.63      0.52      0.46       365
# weighted avg       0.64      0.66      0.56       365

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import pandas as pd

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df_train_a = pd.read_csv('train_data.csv')
# df_test_a = pd.read_csv('test_data.csv')

# 피처 및 타겟 설정
x_train_a = df_train_a[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_a = df_test_a[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_a = df_train_a['현재발전출력_div']
y_test_a = df_test_a['현재발전출력_div']

# 랜덤포레스트 분류기 모델 초기화
# DecisionTreeClassifier의 max_depth를 설정하여 랜덤포레스트의 트리 깊이를 제한
rf_model_a = RandomForestClassifier(
    n_estimators=100, 
    random_state=42, 
    max_depth=3  # 모든 트리의 최대 깊이를 3으로 설정
)

# 모델 훈련
rf_model_a.fit(x_train_a, y_train_a)

# 테스트 세트에 대한 예측
y_pred_a = rf_model_a.predict(x_test_a)

# 정확도 계산
accuracy = accuracy_score(y_test_a, y_pred_a)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_a, y_pred_a)
recall = recall_score(y_test_a, y_pred_a)
precision = precision_score(y_test_a, y_pred_a)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_a, y_pred_a)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('RF classifier - Area A')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_a, y_pred_a, target_names=['Negative (0)', 'Positive (1)']))

# 랜덤포레스트의 첫 번째 의사결정 트리 시각화 (max_depth를 3으로 설정)
# 단일 트리 선택
tree = rf_model_a.estimators_[0]

# 트리 시각화
plt.figure(figsize=(20, 10))
plot_tree(tree, feature_names=['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2'], class_names=['Negative (0)', 'Positive (1)'], filled=True)
plt.title('Decision Tree Visualization (max_depth=3)')
plt.show()
# Out:
# RF classifier - Area A
# Accuracy(정확도): 0.66
# F1 Score: 0.09
# Recall(재현도): 0.05
# Precision(정밀도): 0.67
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.66      0.99      0.79       238
# Positive (1)       0.67      0.05      0.09       127
#
#     accuracy                           0.66       365
#    macro avg       0.66      0.52      0.44       365
# weighted avg       0.66      0.66      0.55       365

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import pandas as pd

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df_train_b = pd.read_csv('train_data.csv')
# df_test_b = pd.read_csv('test_data.csv')

# 피처 및 타겟 설정
x_train_b = df_train_b[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_b = df_test_b[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_b = df_train_b['현재발전출력_div']
y_test_b = df_test_b['현재발전출력_div']

# 랜덤포레스트 분류기 모델 초기화
# DecisionTreeClassifier의 max_depth를 설정하여 랜덤포레스트의 트리 깊이를 제한
rf_model_b = RandomForestClassifier(
    n_estimators=100, 
    random_state=42, 
    max_depth=3  # 모든 트리의 최대 깊이를 3으로 설정
)

# 모델 훈련
rf_model_b.fit(x_train_b, y_train_b)

# 테스트 세트에 대한 예측
y_pred_b = rf_model_b.predict(x_test_b)

# 정확도 계산
accuracy = accuracy_score(y_test_b, y_pred_b)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_b, y_pred_b)
recall = recall_score(y_test_b, y_pred_b)
precision = precision_score(y_test_b, y_pred_b)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_b, y_pred_b)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('RF classifier - Area B')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_b, y_pred_b, target_names=['Negative (0)', 'Positive (1)']))

# 랜덤포레스트의 첫 번째 의사결정 트리 시각화 (max_depth를 3으로 설정)
# 단일 트리 선택
tree = rf_model_b.estimators_[0]

# 트리 시각화
plt.figure(figsize=(20, 10))
plot_tree(tree, feature_names=['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2'], class_names=['Negative (0)', 'Positive (1)'], filled=True)
plt.title('Decision Tree Visualization (max_depth=3)')
plt.show()
# Out:
# RF classifier - Area B
# Accuracy(정확도): 0.74
# F1 Score: 0.04
# Recall(재현도): 0.02
# Precision(정밀도): 0.18
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.76      0.97      0.85       277
# Positive (1)       0.18      0.02      0.04        88
#
#     accuracy                           0.74       365
#    macro avg       0.47      0.50      0.44       365
# weighted avg       0.62      0.74      0.65       365

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import pandas as pd

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df_train_c = pd.read_csv('train_data.csv')
# df_test_c = pd.read_csv('test_data.csv')

# 피처 및 타겟 설정
x_train_c = df_train_c[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_c = df_test_c[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_c = df_train_c['현재발전출력_div']
y_test_c = df_test_c['현재발전출력_div']

# 랜덤포레스트 분류기 모델 초기화
# DecisionTreeClassifier의 max_depth를 설정하여 랜덤포레스트의 트리 깊이를 제한
rf_model_c = RandomForestClassifier(
    n_estimators=100, 
    random_state=42, 
    max_depth=3  # 모든 트리의 최대 깊이를 3으로 설정
)

# 모델 훈련
rf_model_c.fit(x_train_c, y_train_c)

# 테스트 세트에 대한 예측
y_pred_c = rf_model_c.predict(x_test_c)

# 정확도 계산
accuracy = accuracy_score(y_test_c, y_pred_c)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_c, y_pred_c)
recall = recall_score(y_test_c, y_pred_c)
precision = precision_score(y_test_c, y_pred_c)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_c, y_pred_c)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('RF classifier - Area C')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_c, y_pred_c, target_names=['Negative (0)', 'Positive (1)']))

# 랜덤포레스트의 첫 번째 의사결정 트리 시각화 (max_depth를 3으로 설정)
# 단일 트리 선택
tree = rf_model_c.estimators_[0]

# 트리 시각화
plt.figure(figsize=(20, 10))
plot_tree(tree, feature_names=['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2'], class_names=['Negative (0)', 'Positive (1)'], filled=True)
plt.title('Decision Tree Visualization (max_depth=3)')
plt.show()
# Out:
# RF classifier - Area C
# Accuracy(정확도): 0.79
# F1 Score: 0.00
# Recall(재현도): 0.00
# Precision(정밀도): 0.00
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.82      0.96      0.88       300
# Positive (1)       0.00      0.00      0.00        65
#
#     accuracy                           0.79       365
#    macro avg       0.41      0.48      0.44       365
# weighted avg       0.67      0.79      0.73       365

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import pandas as pd

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df_train_d = pd.read_dsv('train_data.csv')
# df_test_d = pd.read_dsv('test_data.csv')

# 피처 및 타겟 설정
x_train_d = df_train_d[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_d = df_test_d[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_d = df_train_d['현재발전출력_div']
y_test_d = df_test_d['현재발전출력_div']

# 랜덤포레스트 분류기 모델 초기화
# DecisionTreeClassifier의 max_depth를 설정하여 랜덤포레스트의 트리 깊이를 제한
rf_model_d = RandomForestClassifier(
    n_estimators=100, 
    random_state=42, 
    max_depth=3  # 모든 트리의 최대 깊이를 3으로 설정
)

# 모델 훈련
rf_model_d.fit(x_train_d, y_train_d)

# 테스트 세트에 대한 예측
y_pred_d = rf_model_d.predict(x_test_d)

# 정확도 계산
accuracy = accuracy_score(y_test_d, y_pred_d)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_d, y_pred_d)
recall = recall_score(y_test_d, y_pred_d)
precision = precision_score(y_test_d, y_pred_d)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_d, y_pred_d)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('RF classifier - Area D')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_d, y_pred_d, target_names=['Negative (0)', 'Positive (1)']))

# 랜덤포레스트의 첫 번째 의사결정 트리 시각화 (max_depth를 3으로 설정)
# 단일 트리 선택
tree = rf_model_d.estimators_[0]

# 트리 시각화
plt.figure(figsize=(20, 10))
plot_tree(tree, feature_names=['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2'], class_names=['Negative (0)', 'Positive (1)'], filled=True)
plt.title('Decision Tree Visualization (max_depth=3)')
plt.show()
# Out:
# RF classifier - Area D
# Accuracy(정확도): 0.79
# F1 Score: 0.05
# Recall(재현도): 0.03
# Precision(정밀도): 0.29
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.80      0.98      0.88       291
# Positive (1)       0.29      0.03      0.05        74
#
#     accuracy                           0.79       365
#    macro avg       0.54      0.50      0.47       365
# weighted avg       0.69      0.79      0.71       365

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import pandas as pd

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df_train_e = pd.read_esv('train_data.csv')
# df_test_d = pd.read_dsv('test_data.csv')

# 피처 및 타겟 설정
x_train_e = df_train_e[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_e = df_test_e[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_e = df_train_e['현재발전출력_div']
y_test_e = df_test_e['현재발전출력_div']

# 랜덤포레스트 분류기 모델 초기화
# DecisionTreeClassifier의 max_eepth를 설정하여 랜덤포레스트의 트리 깊이를 제한
rf_model_e = RandomForestClassifier(
    n_estimators=100, 
    random_state=42, 
    max_depth=3  # 모든 트리의 최대 깊이를 3으로 설정
)

# 모델 훈련
rf_model_e.fit(x_train_e, y_train_e)

# 테스트 세트에 대한 예측
y_pred_e = rf_model_e.predict(x_test_e)

# 정확도 계산
accuracy = accuracy_score(y_test_e, y_pred_e)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_e, y_pred_e)
recall = recall_score(y_test_e, y_pred_e)
precision = precision_score(y_test_e, y_pred_e)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_e, y_pred_e)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('RF classifier - Area E')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_e, y_pred_e, target_names=['Negative (0)', 'Positive (1)']))

# 랜덤포레스트의 첫 번째 의사결정 트리 시각화 (max_eepth를 3으로 설정)
# 단일 트리 선택
tree = rf_model_e.estimators_[0]

# 트리 시각화
plt.figure(figsize=(20, 10))
plot_tree(tree, feature_names=['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2'], class_names=['Negative (0)', 'Positive (1)'], filled=True)
plt.title('Decision Tree Visualization (max_eepth=3)')
plt.show()
# Out:
# RF classifier - Area E
# Accuracy(정확도): 0.79
# F1 Score: 0.03
# Recall(재현도): 0.01
# Precision(정밀도): 0.14
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.81      0.98      0.89       295
# Positive (1)       0.14      0.01      0.03        70
#
#     accuracy                           0.79       365
#    macro avg       0.48      0.50      0.46       365
# weighted avg       0.68      0.79      0.72       365

# %% [markdown]
# ## GBM 분류

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df = pd.read_csv('your_data.csv')

# 피처 및 타겟 설정
x_train_a = df_train_a[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_a = df_test_a[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_a = df_train_a['현재발전출력_div']
y_test_a = df_test_a['현재발전출력_div']




# GBM 분류기 모델 초기화
gbm_model_a = GradientBoostingClassifier(n_estimators=500, learning_rate=0.1, max_depth=3, random_state=0)

# 모델 훈련
gbm_model_a.fit(x_train_a, y_train_a)

# 테스트 세트에 대한 예측
y_pred_a = gbm_model_a.predict(x_test_a)

# 정확도 계산
accuracy = accuracy_score(y_test_a, y_pred_a)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_a, y_pred_a)
recall = recall_score(y_test_a, y_pred_a)
precision = precision_score(y_test_a, y_pred_a)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_a, y_pred_a)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix area A')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('GBM classifier area A')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_a, y_pred_a, target_names=['Negative (0)', 'Positive (1)']))
# Out:
# GBM classifier area A
# Accuracy(정확도): 0.64
# F1 Score: 0.26
# Recall(재현도): 0.18
# Precision(정밀도): 0.44
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.67      0.88      0.76       238
# Positive (1)       0.44      0.18      0.26       127
#
#     accuracy                           0.64       365
#    macro avg       0.56      0.53      0.51       365
# weighted avg       0.59      0.64      0.58       365

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df = pd.read_csv('your_data.csv')

# 피처 및 타겟 설정
x_train_b = df_train_b[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_b = df_test_b[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_b = df_train_b['현재발전출력_div']
y_test_b = df_test_b['현재발전출력_div']




# GBM 분류기 모델 초기화
gbm_model_b = GradientBoostingClassifier(n_estimators=500, learning_rate=0.1, max_depth=3, random_state=0)

# 모델 훈련
gbm_model_b.fit(x_train_b, y_train_b)

# 테스트 세트에 대한 예측
y_pred_b = gbm_model_b.predict(x_test_b)

# 정확도 계산
accuracy = accuracy_score(y_test_b, y_pred_b)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_b, y_pred_b)
recall = recall_score(y_test_b, y_pred_b)
precision = precision_score(y_test_b, y_pred_b)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_b, y_pred_b)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix area B')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('GBM classifier area B')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_b, y_pred_b, target_names=['Negative (0)', 'Positive (1)']))
# Out:
# GBM classifier area B
# Accuracy(정확도): 0.69
# F1 Score: 0.10
# Recall(재현도): 0.07
# Precision(정밀도): 0.17
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.75      0.89      0.82       277
# Positive (1)       0.17      0.07      0.10        88
#
#     accuracy                           0.69       365
#    macro avg       0.46      0.48      0.46       365
# weighted avg       0.61      0.69      0.64       365

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df = pd.read_csv('your_data.csv')

# 피처 및 타겟 설정
x_train_c = df_train_c[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_c = df_test_c[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_c = df_train_c['현재발전출력_div']
y_test_c = df_test_c['현재발전출력_div']




# GBM 분류기 모델 초기화
gbm_model_c = GradientBoostingClassifier(n_estimators=500, learning_rate=0.1, max_depth=3, random_state=0)

# 모델 훈련
gbm_model_c.fit(x_train_c, y_train_c)

# 테스트 세트에 대한 예측
y_pred_c = gbm_model_c.predict(x_test_c)

# 정확도 계산
accuracy = accuracy_score(y_test_c, y_pred_c)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_c, y_pred_c)
recall = recall_score(y_test_c, y_pred_c)
precision = precision_score(y_test_c, y_pred_c)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_c, y_pred_c)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix area C')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('GBM classifier area C')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_c, y_pred_c, target_names=['Negative (0)', 'Positive (1)']))
# Out:
# GBM classifier area C
# Accuracy(정확도): 0.78
# F1 Score: 0.09
# Recall(재현도): 0.06
# Precision(정밀도): 0.17
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.82      0.93      0.87       300
# Positive (1)       0.17      0.06      0.09        65
#
#     accuracy                           0.78       365
#    macro avg       0.49      0.50      0.48       365
# weighted avg       0.70      0.78      0.73       365

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df = pd.read_dsv('your_data.csv')

# 피처 및 타겟 설정
x_train_d = df_train_d[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_d = df_test_d[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_d = df_train_d['현재발전출력_div']
y_test_d = df_test_d['현재발전출력_div']




# GBM 분류기 모델 초기화
gbm_model_d = GradientBoostingClassifier(n_estimators=500, learning_rate=0.1, max_depth=3, random_state=0)

# 모델 훈련
gbm_model_d.fit(x_train_d, y_train_d)

# 테스트 세트에 대한 예측
y_pred_d = gbm_model_d.predict(x_test_d)

# 정확도 계산
accuracy = accuracy_score(y_test_d, y_pred_d)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_d, y_pred_d)
recall = recall_score(y_test_d, y_pred_d)
precision = precision_score(y_test_d, y_pred_d)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_d, y_pred_d)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix area D')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('GBM classifier area D')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_d, y_pred_d, target_names=['Negative (0)', 'Positive (1)']))
# Out:
# GBM classifier area D
# Accuracy(정확도): 0.74
# F1 Score: 0.10
# Recall(재현도): 0.07
# Precision(정밀도): 0.16
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.79      0.91      0.85       291
# Positive (1)       0.16      0.07      0.10        74
#
#     accuracy                           0.74       365
#    macro avg       0.48      0.49      0.47       365
# weighted avg       0.67      0.74      0.70       365

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 예제 데이터프레임 생성 (실제 데이터프레임을 사용해야 합니다)
# df = pd.read_esv('your_eata.csv')

# 피처 및 타겟 설정
x_train_e = df_train_e[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]
x_test_e = df_test_e[['수평일사량1', '수평일사량2', '경사일사량1', '경사일사량2', '외기온도1', '외기온도2']]

y_train_e = df_train_e['현재발전출력_div']
y_test_e = df_test_e['현재발전출력_div']




# GBM 분류기 모델 초기화
gbm_model_e = GradientBoostingClassifier(n_estimators=500, learning_rate=0.1, max_depth=3, random_state=0)

# 모델 훈련
gbm_model_e.fit(x_train_e, y_train_e)

# 테스트 세트에 대한 예측
y_pred_e = gbm_model_e.predict(x_test_e)

# 정확도 계산
accuracy = accuracy_score(y_test_e, y_pred_e)

# F1-score, Recall, Precision 계산
f1 = f1_score(y_test_e, y_pred_e)
recall = recall_score(y_test_e, y_pred_e)
precision = precision_score(y_test_e, y_pred_e)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test_e, y_pred_e)

# 혼동 행렬 시각화
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative (0)', 'Positive (1)'], yticklabels=['Negative (0)', 'Positive (1)'])
plt.title('Confusion Matrix area E')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# 결과 출력
print('GBM classifier area E')
print(f"Accuracy(정확도): {accuracy:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Recall(재현도): {recall:.2f}")
print(f"Precision(정밀도): {precision:.2f}")

# 상세한 성능 보고서 출력
print("\nClassification Report:")
print(classification_report(y_test_e, y_pred_e, target_names=['Negative (0)', 'Positive (1)']))
# Out:
# GBM classifier area E
# Accuracy(정확도): 0.78
# F1 Score: 0.20
# Recall(재현도): 0.14
# Precision(정밀도): 0.31
#
# Classification Report:
#               precision    recall  f1-score   support
#
# Negative (0)       0.82      0.93      0.87       295
# Positive (1)       0.31      0.14      0.20        70
#
#     accuracy                           0.78       365
#    macro avg       0.57      0.53      0.53       365
# weighted avg       0.72      0.78      0.74       365
