# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:/Users/campus4D037/iM DiGital Bank/ML/datas/Project_Data1.xlsx")
pd.set_option('display.precision', 8)

# %%
df.head()
# Out:
#   위치         일자        현재발전출력        수평일사량1        수평일사량2        경사일사량1  \
# 0  A 2019-01-01  110.65736944  126.17731377  154.39764758  132.25960291
# 1  A 2019-01-02  328.85723337  352.84609330  372.68351037  382.95900078
# 2  A 2019-01-03  344.74021549  388.09737487  424.30190436  421.36298614
# 3  A 2019-01-04  359.59558933  358.81310209  383.93011428  380.41951197
# 4  A 2019-01-05  358.73768471  319.16586744  355.00710978  338.56756772
#
#          경사일사량2        외기온도1        외기온도2
# 0  160.38297847  14.84114575  15.42837834
# 1  406.38263633  15.68541659  14.83735470
# 2  459.24644320  15.18928582  16.40785135
# 3  407.34017451  15.93553716  16.10220123
# 4  379.14657169  16.57913544  16.85949994

# %%
df['일자'].value_counts()
# Out:
# 일자
# 2019-01-01    5
# 2020-09-05    5
# 2016-08-30    5
# 2016-08-31    5
# 2020-09-01    5
#              ..
# 2021-05-05    5
# 2021-05-04    5
# 2021-05-03    5
# 2021-05-02    5
# 2021-12-31    5
# Name: count, Length: 2190, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# Matplotlib을 사용한 Boxplot 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(df['수평일사량1'])
plt.title('Boxplot of Horizontal Irradiance (Matplotlib)')
plt.ylabel('Horizontal Irradiance')
plt.show()

# %%
df_a = df[df['위치'] == 'A']

# %%
df_a.head()
# Out:
#   위치         일자        현재발전출력        수평일사량1        수평일사량2        경사일사량1  \
# 0  A 2019-01-01  110.65736944  126.17731377  154.39764758  132.25960291
# 1  A 2019-01-02  328.85723337  352.84609330  372.68351037  382.95900078
# 2  A 2019-01-03  344.74021549  388.09737487  424.30190436  421.36298614
# 3  A 2019-01-04  359.59558933  358.81310209  383.93011428  380.41951197
# 4  A 2019-01-05  358.73768471  319.16586744  355.00710978  338.56756772
#
#          경사일사량2        외기온도1        외기온도2
# 0  160.38297847  14.84114575  15.42837834
# 1  406.38263633  15.68541659  14.83735470
# 2  459.24644320  15.18928582  16.40785135
# 3  407.34017451  15.93553716  16.10220123
# 4  379.14657169  16.57913544  16.85949994

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# Matplotlib을 사용한 Boxplot 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(df_a['수평일사량1'])
plt.title('지역A 수평일사량1 ')
plt.ylabel('수평일사량1')
plt.show()

# %%
df_a['수평일사량1'].value_counts()
# Out:
# 수평일사량1
# 146.159988    7
# 317.208020    5
# 163.800003    5
# 366.835466    5
# 112.748096    5
#              ..
# 66.294040     1
# 362.690519    1
# 320.958699    1
# 355.739027    1
# 94.041242     1
# Name: count, Length: 2107, dtype: int64

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# Matplotlib을 사용한 Boxplot 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(df_a['수평일사량2'])
plt.title('지역A 수평일사량2 ')
plt.ylabel('수평일사량2')
plt.show()

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# Matplotlib을 사용한 Boxplot 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(df_a['경사일사량1'])
plt.title('지역A 경사일사량1 ')
plt.ylabel('경사일사량1')
plt.show()

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# Matplotlib을 사용한 Boxplot 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(df_a['경사일사량2'])
plt.title('지역A 경사일사량2')
plt.ylabel('경사일사량2')
plt.show()

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# Matplotlib을 사용한 Boxplot 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(df_a['외기온도2'])
plt.title('지역A 외기온도2')
plt.ylabel('외기온도2')
plt.show()

# %%
df_a[df_a['외기온도1'] >= 20]
# Out:
#      위치         일자      현재발전출력       수평일사량1        수평일사량2       경사일사량1  \
# 1104  A 2020-07-19  167.355896  146.1599884  164.88000488  162.3999939
# 1105  A 2020-07-20  167.355896  146.1599884  164.88000488  162.3999939
# 1106  A 2020-07-21  167.355896  146.1599884  164.88000488  162.3999939
# 1107  A 2020-07-22  167.355896  146.1599884  164.88000488  162.3999939
# 1108  A 2020-07-23  167.355896  146.1599884  164.88000488  162.3999939
# 1109  A 2020-07-24  167.355896  146.1599884  164.88000488  162.3999939
# 1110  A 2020-07-25  167.355896  146.1599884  164.88000488  162.3999939
#
#             경사일사량2        외기온도1        외기온도2
# 1104  183.19999695  22.70000076  22.67499924
# 1105  183.19999695  22.70000076  22.67499924
# 1106  183.19999695  22.70000076  22.67499924
# 1107  183.19999695  22.70000076  22.67499924
# 1108  183.19999695  22.70000076  22.67499924
# 1109  183.19999695  22.70000076  22.67499924
# 1110  183.19999695  22.70000076  22.67499924

# %%
df_a['외기온도1'].value_counts()
# Out:
# 외기온도1
# 22.70000076    7
# 14.86735547    5
# 9.70000076     5
# 15.83822107    5
# 15.47611101    5
#               ..
# 10.02847557    1
# 7.10357894     1
# 6.22392187     1
# 0.40894154     1
# 4.77242822     1
# Name: count, Length: 2107, dtype: int64

# %%
dup_a = df_a.drop(columns = '일자')[df_a.drop(columns = '일자').duplicated()]
dup_a
# Out:
#      위치        현재발전출력        수평일사량1        수평일사량2        경사일사량1        경사일사량2  \
# 18    A  130.28477128  113.53530861  130.10685916  122.00848065  134.94733724
# 19    A  405.49005237  459.75178832  483.32526745  493.51459793  507.05879832
# 20    A  383.29920523  409.20955421  452.16850737  442.49222057  482.87272665
# 21    A  340.81257243  349.54498002  357.91306955  383.87921925  384.02864867
# 22    A  320.89836542  317.20802026  362.42084454  344.41398328  382.53625231
# ...  ..           ...           ...           ...           ...           ...
# 1656  A   31.01933479   19.44000053   24.11999893   21.60000038   26.79999924
# 1839  A  219.23254395  163.80000305  275.04000854  182.00000000  305.60000610
# 1840  A  219.23254395  163.80000305  275.04000854  182.00000000  305.60000610
# 1841  A  219.23254395  163.80000305  275.04000854  182.00000000  305.60000610
# 1842  A  219.23254395  163.80000305  275.04000854  182.00000000  305.60000610
#
#             외기온도1        외기온도2
# ...

# %%
df_a.round(3)
# Out:
#      위치         일자   현재발전출력   수평일사량1   수평일사량2   경사일사량1   경사일사량2   외기온도1  \
# 0     A 2019-01-01  110.657  126.177  154.398  132.260  160.383  14.841
# 1     A 2019-01-02  328.857  352.846  372.684  382.959  406.383  15.685
# 2     A 2019-01-03  344.740  388.097  424.302  421.363  459.246  15.189
# 3     A 2019-01-04  359.596  358.813  383.930  380.420  407.340  15.936
# 4     A 2019-01-05  358.738  319.166  355.007  338.568  379.147  16.579
# ...  ..        ...      ...      ...      ...      ...      ...     ...
# 2185  A 2021-12-27   21.294   50.585   61.003   81.105  264.369   4.879
# 2186  A 2021-12-28   40.126   50.695  147.967  132.550   12.859   1.608
# 2187  A 2021-12-29   47.545  164.334  206.717   72.615  268.202   5.355
# 2188  A 2021-12-30  215.763   76.782  218.700   32.340  125.940   5.353
# 2189  A 2021-12-31  161.805   94.041  188.463   90.803  233.209   4.772
#
#        외기온도2
# 0     15.428
# 1     14.837
# 2     16.408
# 3     16.102
# 4     16.859
# ...      ...
# ...

# %%
df['위치'].value_counts()
# Out:
# 위치
# A    2190
# B    2190
# C    2190
# D    2190
# E    2190
# Name: count, dtype: int64

# %%
df_a.round(3)
# Out:
#      위치         일자   현재발전출력   수평일사량1   수평일사량2   경사일사량1   경사일사량2   외기온도1  \
# 0     A 2019-01-01  110.657  126.177  154.398  132.260  160.383  14.841
# 1     A 2019-01-02  328.857  352.846  372.684  382.959  406.383  15.685
# 2     A 2019-01-03  344.740  388.097  424.302  421.363  459.246  15.189
# 3     A 2019-01-04  359.596  358.813  383.930  380.420  407.340  15.936
# 4     A 2019-01-05  358.738  319.166  355.007  338.568  379.147  16.579
# ...  ..        ...      ...      ...      ...      ...      ...     ...
# 2185  A 2021-12-27   21.294   50.585   61.003   81.105  264.369   4.879
# 2186  A 2021-12-28   40.126   50.695  147.967  132.550   12.859   1.608
# 2187  A 2021-12-29   47.545  164.334  206.717   72.615  268.202   5.355
# 2188  A 2021-12-30  215.763   76.782  218.700   32.340  125.940   5.353
# 2189  A 2021-12-31  161.805   94.041  188.463   90.803  233.209   4.772
#
#        외기온도2
# 0     15.428
# 1     14.837
# 2     16.408
# 3     16.102
# 4     16.859
# ...      ...
# ...

# %%
df_a['현재발전출력'].max()
# Out:
# 462.3694548728571

# %%
df_a[df_a['현재발전출력'] == 462.3694548728571]
# Out:
#     위치         일자        현재발전출력        수평일사량1        수평일사량2        경사일사량1  \
# 744  A 2021-05-25  462.36945487  397.21595162  464.21120281  429.31903534
#
#            경사일사량2       외기온도1        외기온도2
# 744  485.83790872  10.1566761  10.11241555

# %%
df_a['년도'] = df_a['일자'].dt.year
df_a['월'] = df_a['일자'].dt.month
df_a.head(800)
# Out:
# C:\Users\campus4D037\AppData\Local\Temp\ipykernel_17552\663939258.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a['년도'] = df_a['일자'].dt.year
# C:\Users\campus4D037\AppData\Local\Temp\ipykernel_17552\663939258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a['월'] = df_a['일자'].dt.month
#     위치         일자        현재발전출력        수평일사량1        수평일사량2        경사일사량1  \
# 0    A 2019-01-01  110.65736944  126.17731377  154.39764758  132.25960291
# ...

# %%
df.groupby('월')['경사일사량1'].mean()
# Out:
# 월
# 1     277.95618327
# 2     289.41650186
# 3     317.62784878
# 4     340.10196868
# 5     306.94058188
# 6     292.10245134
# 7     258.28254320
# 8     276.21324612
# 9     195.68663490
# 10    191.59414674
# 11    231.60317215
# 12    245.47940027
# Name: 경사일사량1, dtype: float64

# %%
# 월 변수에 one-hot encoding 적용
df_onehot = pd.get_dummies(df['월'], prefix='월')

# 원본 데이터프레임에 one-hot encoding된 변수 추가
df = pd.concat([df, df_onehot], axis=1)

df.colums
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[209], line 7
#       4 # 원본 데이터프레임에 one-hot encoding된 변수 추가
#       5 df = pd.concat([df, df_onehot], axis=1)
# ----> 7 df.columsn
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'columsn'
