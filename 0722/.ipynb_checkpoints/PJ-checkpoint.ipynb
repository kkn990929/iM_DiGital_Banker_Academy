# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
matplotlib.rc('font', family = 'Malgun Gothic')
matplotlib.rc('axes', unicode_minus=False)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bank.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3748 entries, 0 to 3747
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BAD      3748 non-null   int64
#  1   LOAN     3748 non-null   int64
#  2   MORTDUE  3748 non-null   int64
#  3   VALUE    3734 non-null   float64
#  4   REASON   3748 non-null   object
#  5   JOB      3667 non-null   object
#  6   YOJ      3543 non-null   float64
#  7   DEROG    3748 non-null   int64
#  8   DELINQ   3718 non-null   float64
#  9   CLAGE    3711 non-null   float64
#  10  NINQ     3692 non-null   float64
#  11  CLNO     3748 non-null   int64
#  12  DEBTINC  3748 non-null   float64
# dtypes: float64(6), int64(5), object(2)
# memory usage: 380.8+ KB

# %%
df.isnull().sum()
# Out:
# BAD          0
# LOAN         0
# MORTDUE      0
# VALUE       14
# REASON       0
# JOB         81
# YOJ        205
# DEROG        0
# DELINQ      30
# CLAGE       37
# NINQ        56
# CLNO         0
# DEBTINC      0
# dtype: int64

# %%
sns.displot(df, x = 'LOAN')

# %%
sns.displot(df, x = 'MORTDUE')

# %%
sns.displot(df, x = 'VALUE')

# %%
sns.displot(df, x = 'DELINQ')

# %%
sns.displot(df, x = 'YOJ')

# %%
df['YOJ'].value_counts()
# Out:
# YOJ
# 0.0     307
# 4.0     241
# 1.0     232
# 2.0     230
# 3.0     216
# 6.0     207
# 5.0     206
# 9.0     193
# 10.0    167
# 7.0     163
# 8.0     162
# 13.0    117
# 11.0    114
# 14.0     94
# 12.0     94
# 15.0     89
# 16.0     85
# 19.0     70
# 17.0     64
# 23.0     56
# 18.0     55
# 21.0     54
# 20.0     54
# 24.0     51
# 22.0     50
# 25.0     39
# 27.0     29
# 28.0     25
# 26.0     24
# 29.0     22
# 30.0     16
# 31.0      5
# 35.0      5
# 36.0      4
# 41.0      1
# 34.0      1
# 32.0      1
# Name: count, dtype: int64

# %%
df[df.isnull().any(axis=1)]['BAD']
# Out:
# 10      1
# 17      0
# 44      0
# 49      0
# 58      0
#        ..
# 3732    0
# 3733    0
# 3734    0
# 3735    0
# 3736    0
# Name: BAD, Length: 384, dtype: int64

# %%
# 원본데이터와 비율이 차이가 나지 않으므로 제거한다.

# %%
df['JOB'].value_counts()
# MGR = 노동자
# office = 사무직
# ProfExe = 숙련기술자
# sales = 판매업
# self = 자영업
# Out:
# JOB
# Other      1444
# ProfExe     929
# Office      623
# Mgr         477
# Self        130
# Sales        64
# Name: count, dtype: int64

# %%
# 원래 데이터의 비율을 해치지 않는다. 데이터 왜곡이 없으며, 결측치 비율이 10% 적고, 
# 결측치인 행의 BAD비율도 원 데이터와 차이가 없음.
# 따라서 결측치 제거

# %%
df[df.isnull().any(axis=1)]['BAD'].value_counts()
# Out:
# BAD
# 0    339
# 1     45
# Name: count, dtype: int64

# %%
df['BAD'].value_counts()
# Out:
# BAD
# 0    3403
# 1     345
# Name: count, dtype: int64

# %%
df_raw = df.dropna()

# %%
df_raw.isnull().sum()
# Out:
# BAD        0
# LOAN       0
# MORTDUE    0
# VALUE      0
# REASON     0
# JOB        0
# YOJ        0
# DEROG      0
# DELINQ     0
# CLAGE      0
# NINQ       0
# CLNO       0
# DEBTINC    0
# dtype: int64

# %%
sns.displot(df, x = 'CLAGE')

# %%
df.boxplot(column = df.columns[9])
# Out:
# <Axes: >

# %%
df_raw = df_raw.drop(df[df['CLAGE'] > 1000].index)
df_raw
# Out:
#       BAD   LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0       1   1700    30548   40320.0  HomeImp   Other   9.0      0     0.0
# 1       1   1800    28502   43034.0  HomeImp   Other  11.0      0     0.0
# 2       0   2300   102370  120953.0  HomeImp  Office   2.0      0     0.0
# 3       1   2400    34863   47471.0  HomeImp     Mgr  12.0      0     0.0
# 4       0   2400    98449  117195.0  HomeImp  Office   4.0      0     0.0
# ...   ...    ...      ...       ...      ...     ...   ...    ...     ...
# 3743    0  88900    57264   90185.0  DebtCon   Other  16.0      0     0.0
# 3744    0  89000    54576   92937.0  DebtCon   Other  16.0      0     0.0
# 3745    0  89200    54045   92924.0  DebtCon   Other  15.0      0     0.0
# 3746    0  89800    50370   91861.0  DebtCon   Other  14.0      0     0.0
# 3747    0  89900    48811   88934.0  DebtCon   Other  15.0      0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# ...

# %%
sns.displot(df_raw, x = 'CLNO')

# %%
df_raw.boxplot(column = df_raw.columns[11])
# Out:
# <Axes: >

# %%
sns.displot(df_raw, x = 'DEBTINC')

# %%
sns.displot(df_raw, x = 'BAD')

# %%
sns.displot(df_raw, x = 'REASON')

# %%
sns.displot(df_raw, x = 'JOB')  # 신용한도점수로 직업별 평균비교

# %%
sns.displot(df_raw, x = 'YOJ') # 연속형

# %%
sns.displot(df_raw, x = 'DEROG') # 0,1,2 이상

# %%
sns.displot(df_raw, x = 'DELINQ') # 신용한도 점수랑 같이 0,1,2

# %%
sns.displot(df_raw, x = 'NINQ') # 0,1,2,3
